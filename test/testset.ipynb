# %%
# %pylab inline
import sys
sys.path.append('.')
import sklearn.datasets
sys.path.append('../')
import GSOM
import SOMTools
import SOMclust
import SOMgraph
import itertools
import scipy.spatial.distance
from priodict import priorityDictionary
#pylab.rcParams['figure.figsize'] = 6, 6  # that's default image size for this interactive session
from IPython.display import clear_output
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload
# %autoreload 2

# %%
xy, c = sklearn.datasets.make_blobs(n_samples=5000, centers=3)
x, y = xy[:,0], xy[:,1]

# %%
scatter(x, y, c=c)

# %%
xy.shape
# Out:
# (5000, 2)

# %%
#save('inputmatrix', xy)

# %%
gsom = GSOM.GSOM(xy, growing_threshold=1.)
# Out:
# Map initialization...
# Shape of the SOM:(3, 3, 2)
# Map initialization...

# %%
smap = gsom.learn(verbose=True)
# Out:
# Learning for 5000 vectors
# 5000 iterations
# 10000 iterations
# Training phase 1 : 100%[========================================]Time: 00:00:04
# Training phase 2 : 100%[========================================]Time: 00:00:10

# %%
imshow(ma.masked_array(log(SOMTools.getUmatrix(gsom.smap, toricMap=False)), gsom.smap.mask[:,:,0]), interpolation='nearest')
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x1360ab00>

# %%
matshow(gsom.smap.sum(axis=2))
