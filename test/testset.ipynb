# %%
# %pylab inline
import sys
sys.path.append('.')
import sklearn.datasets
sys.path.append('../')
import GSOM
import SOMTools
import SOMclust
import SOMgraph
import itertools
import scipy.spatial.distance
from priodict import priorityDictionary
#pylab.rcParams['figure.figsize'] = 6, 6  # that's default image size for this interactive session
from IPython.display import clear_output
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload
# %autoreload 2

# %%
xy, c = sklearn.datasets.make_blobs(n_samples=500, centers=10)
x, y = xy[:,0], xy[:,1]

# %%
scatter(x, y, c=c)

# %%
xy.shape
# Out:
# (500, 2)

# %%
#save('inputmatrix', xy)

# %%
gsom = GSOM.GSOM(xy)
# Out:
# Map initialization...
# Shape of the SOM:(3, 3, 2)
# Map initialization...

# %%
gsom.grow((1,1))
matshow(gsom.smap.sum(axis=2))

# %%
k = 100
t = 0
trainingPhase = 0
bmu, dist = gsom.som.findBMU(k, gsom.smap, return_distance=True)
print bmu, dist
gsom.som.adjustment(k, t, trainingPhase, gsom.smap, bmu)
# Out:
# (2, 3) 1.53896555354
# masked_array(data =
#  [[[-- --]
#   [-- --]
#   [-- --]
#   [-- --]
#   [-- --]
#   [-- --]]
#
#  [[-- --]
#   [1.64045703255 1.93755273509]
#   [4.23655030601 0.557801890425]
#   [-- --]
#   [-- --]
#   [-- --]]
#
#  [[-- --]
#   [3.28646125025 -1.83567675945]
#   [2.9732179596 -0.168341679966]
#   [-0.760129999133 0.119608227815]
#   [1.67059183483 6.22377751074]
#   [-- --]]
#
#  [[-- --]
#   [-- --]
#   [-0.476407630757 2.94605951702]
#   [-2.70832502974 5.69077621228]
#   [-1.59149739235 2.86557946045]
#   [-- --]]
#
#  [[-- --]
#   [-- --]
#   [0.872047958922 3.86423981323]
#   [1.73613692047 2.25240522628]
#   [-2.96259178267 2.05049430063]
#   [-- --]]
#
#  [[-- --]
#   [-- --]
#   [-- --]
#   [-- --]
#   [-- --]
#   [-- --]]],
#              mask =
#  [[[ True  True]
#   [ True  True]
#   [ True  True]
#   [ True  True]
#   [ True  True]
#   [ True  True]]
#
#  [[ True  True]
#   [False False]
#   [False False]
#   [ True  True]
#   [ True  True]
# ...
