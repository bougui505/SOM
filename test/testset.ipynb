# %%
import sys
sys.path.append('.')
import generatedatasets
sys.path.append('../')
import SOM2
import SOMTools
import SOMclust
import SOMgraph
import itertools
pylab.rcParams['figure.figsize'] = 10, 10  # that's default image size for this interactive session

# %%
# %load_ext autoreload
# %autoreload 2

# %%
xy, c = generatedatasets.dataset_fixed_cov()
x, y = xy[:,0], xy[:,1]

# %%
scatter(x, y, c=c)

# %%
xy.shape
# Out:
# (600, 2)

# %%
#save('inputmatrix', xy)

# %%
som = SOM2.SOM(xy)

# %%
som.learn(verbose=True)
# Out:
# 0 0 600 0.00% 6.25 0.5 (12, 3)
# 0
#  100 600 16.67% 3.61384570922 0.297218900709 (6, 45)
# 0
#  200 600 33.33% 3.11594047838 0.258918498337 (45, 46)
# 0
#  300 600 50.00% 3.02189832775 0.25168448675 (14, 46)
# 0
#  400 600 66.67% 3.00413605985 0.25031815845 (14, 36)
# 0
#  500 600 83.33% 3.0007812008 0.250060092369 (45, 8)
# 1
#  0 1200 0.00% 4.0 0.25 (40, 23)
# 1
#  100 1200 8.33% 2.30379462552 0.108649552127 (47, 41)
# 1
#  200 1200 16.67% 1.56662680851 0.0472189007094 (11, 1)
# 1
#  300 1200 25.00% 1.24625499587 0.020521249656 (43, 39)
# 1
#  400 1200 33.33% 1.10702198004 0.00891849833681 (0, 42)
# 1
#  500 1200 41.67% 1.0465115608 0.00387596339975 (0, 41)
# 1
#  600 1200 50.00% 1.020213841 0.00168448674977 (40, 23)
# 1
#  700 1200 58.33% 1.00878489908 0.000732074923705 (47, 40)
# 1
#  800 1200 66.67% 1.0038179014 0.000318158450335 (11, 1)
# 1
#  900 1200 75.00% 1.00165925311 0.000138271092537 (43, 39)
# 1
#  1000 1200 83.33% 1.00072110843 6.00923691049e-05 (0, 42)
# 1
#  1100 1200 91.67% 1.00031339243 2.61160359579e-05 (0, 41)
# array([[[ 3.18310449,  3.74548462],
#         [ 2.52678175,  3.15468271],
#         [ 1.7986011 ,  2.48879473],
#         ...,
#         [ 4.39397622,  4.7808987 ],
#         [ 4.11277198,  4.55147085],
#         [ 3.7158179 ,  4.21373227]],
#
#        [[ 3.47601981,  4.0981876 ],
#         [ 2.9562802 ,  3.63579628],
#         [ 2.33492604,  3.06915325],
#         ...,
#         [ 4.40163813,  4.86138682],
#         [ 4.18329213,  4.69308103],
#         [ 3.88191448,  4.44656345]],
#
#        [[ 3.69402793,  4.36860699],
#         [ 3.302703  ,  4.02667736],
#         [ 2.80908382,  3.58011801],
#         ...,
#         [ 4.39390796,  4.91825391],
#         [ 4.22256735,  4.79552035],
#         [ 3.99506947,  4.61871145]],
#
#        ...,
#        [[ 2.08479232,  2.46680902],
#         [ 1.19425896,  1.66563433],
#         [ 0.45987575,  1.00251994],
#         ...,
#         [ 4.29345522,  4.4300311 ],
#         [ 3.74069556,  3.94372983],
#         [ 2.98264857,  3.27065231]],
#
#        [[ 2.44978497,  2.88814159],
#         [ 1.59026652,  2.1113156 ],
#         [ 0.8063265 ,  1.39849527],
#         ...,
#         [ 4.3354492 ,  4.55843791],
#         [ 3.88264248,  4.16498969],
#         [ 3.246991  ,  3.60255424]],
#
#        [[ 2.83014078,  3.32970395],
#         [ 2.0527738 ,  2.62621976],
#         [ 1.26629997,  1.90831327],
#         ...,
#         [ 4.3708396 ,  4.6780782 ],
#         [ 4.01067755,  4.37243046],
#         [ 3.49960653,  3.92621398]]])

# %%
umat = SOMTools.getUmatrix(som.smap)

# %%
matshow(umat)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x2b1f69303b48>

# %%
bmus = som.get_allbmus()

# %%
reload(SOMclust)
clust = SOMclust.clusters(umat, bmus, som.smap)
# Out:
# 0.96/100: flooding: 24/2499, 0.03, (106, 134)
# 1.92/100: flooding: 48/2499, 0.03, (103, 134)
# 2.88/100: flooding: 72/2499, 0.04, (106, 130)
# 3.84/100: flooding: 96/2499, 0.04, (102, 131)
# 4.80/100: flooding: 120/2499, 0.04, (101, 137)
# 5.76/100: flooding: 144/2499, 0.05, (115, 135)
# 6.72/100: flooding: 168/2499, 0.05, (97, 140)
# 7.68/100: flooding: 192/2499, 0.05, (109, 131)
# 8.64/100: flooding: 216/2499, 0.06, (111, 132)
# 9.60/100: flooding: 240/2499, 0.06, (113, 146)
# 10.56/100: flooding: 264/2499, 0.06, (110, 144)
# 11.52/100: flooding: 288/2499, 0.06, (110, 142)
# 12.48/100: flooding: 312/2499, 0.06, (108, 149)
# 13.45/100: flooding: 336/2499, 0.06, (108, 143)
# 14.41/100: flooding: 360/2499, 0.07, (107, 147)
# 15.37/100: flooding: 384/2499, 0.07, (119, 138)
# 16.33/100: flooding: 408/2499, 0.08, (116, 147)
# 17.29/100: flooding: 432/2499, 0.08, (89, 138)
# 18.25/100: flooding: 456/2499, 0.07, (83, 140)
# 19.21/100: flooding: 480/2499, 0.09, (104, 146)
# 20.17/100: flooding: 504/2499, 0.09, (90, 141)
# 21.13/100: flooding: 528/2499, 0.10, (94, 132)
# 22.09/100: flooding: 552/2499, 0.11, (101, 145)
# 23.05/100: flooding: 576/2499, 0.12, (105, 127)
# 24.01/100: flooding: 600/2499, 0.13, (115, 132)
# 24.97/100: flooding: 624/2499, 0.14, (81, 140)
# 25.93/100: flooding: 648/2499, 0.15, (97, 130)
# 26.89/100: flooding: 672/2499, 0.17, (98, 145)
# 27.85/100: flooding: 696/2499, 0.19, (124, 139)
# 28.81/100: flooding: 720/2499, 0.21, (106, 152)
# 29.77/100: flooding: 744/2499, 0.23, (107, 126)
# 30.73/100: flooding: 768/2499, 0.25, (121, 146)
# 31.69/100: flooding: 792/2499, 0.28, (122, 137)
# 32.65/100: flooding: 816/2499, 0.30, (114, 155)
# 33.61/100: flooding: 840/2499, 0.33, (110, 157)
# 34.57/100: flooding: 864/2499, 0.36, (89, 145)
# 35.53/100: flooding: 888/2499, 0.40, (95, 146)
# 36.49/100: flooding: 912/2499, 0.43, (102, 150)
# 37.45/100: flooding: 936/2499, 0.46, (116, 155)
# 38.42/100: flooding: 960/2499, 0.07, (114, 167)
# 39.38/100: flooding: 984/2499, 0.05, (128, 171)
# 40.34/100: flooding: 1008/2499, 0.05, (128, 167)
# 41.30/100: flooding: 1032/2499, 0.04, (132, 156)
# 42.26/100: flooding: 1056/2499, 0.05, (128, 160)
# 43.22/100: flooding: 1080/2499, 0.05, (129, 156)
# 44.18/100: flooding: 1104/2499, 0.05, (137, 167)
# 45.14/100: flooding: 1128/2499, 0.06, (135, 170)
# 46.10/100: flooding: 1152/2499, 0.06, (126, 175)
# 47.06/100: flooding: 1176/2499, 0.06, (136, 163)
# 48.02/100: flooding: 1200/2499, 0.06, (140, 159)
# 48.98/100: flooding: 1224/2499, 0.07, (125, 167)
# 49.94/100: flooding: 1248/2499, 0.07, (128, 175)
# 50.90/100: flooding: 1272/2499, 0.07, (124, 165)
# 51.86/100: flooding: 1296/2499, 0.08, (143, 157)
# 52.82/100: flooding: 1320/2499, 0.08, (140, 164)
# 53.78/100: flooding: 1344/2499, 0.08, (124, 162)
# 54.74/100: flooding: 1368/2499, 0.09, (142, 169)
# 55.70/100: flooding: 1392/2499, 0.09, (143, 162)
# 56.66/100: flooding: 1416/2499, 0.09, (117, 165)
# 57.62/100: flooding: 1440/2499, 0.10, (140, 155)
# 58.58/100: flooding: 1464/2499, 0.10, (148, 159)
# 59.54/100: flooding: 1488/2499, 0.11, (119, 163)
# 60.50/100: flooding: 1512/2499, 0.12, (143, 170)
# 61.46/100: flooding: 1536/2499, 0.13, (129, 152)
# 62.42/100: flooding: 1560/2499, 0.13, (114, 171)
# 63.39/100: flooding: 1584/2499, 0.15, (147, 168)
# 64.35/100: flooding: 1608/2499, 0.16, (120, 174)
# 65.31/100: flooding: 1632/2499, 0.17, (118, 173)
# 66.27/100: flooding: 1656/2499, 0.19, (149, 168)
# 67.23/100: flooding: 1680/2499, 0.21, (153, 162)
# 68.19/100: flooding: 1704/2499, 0.23, (117, 161)
# 69.15/100: flooding: 1728/2499, 0.25, (143, 153)
# 70.11/100: flooding: 1752/2499, 0.28, (113, 172)
# 71.07/100: flooding: 1776/2499, 0.31, (125, 180)
# 72.03/100: flooding: 1800/2499, 0.34, (109, 163)
# 72.99/100: flooding: 1824/2499, 0.36, (122, 156)
# 73.95/100: flooding: 1848/2499, 0.40, (112, 162)
# 74.91/100: flooding: 1872/2499, 0.44, (153, 159)
# 75.87/100: flooding: 1896/2499, 0.47, (126, 149)
# 76.83/100: flooding: 1920/2499, 0.49, (150, 170)
# 77.79/100: flooding: 1944/2499, 0.50, (117, 130)
# 78.75/100: flooding: 1968/2499, 0.51, (81, 143)
# 79.71/100: flooding: 1992/2499, 0.53, (114, 157)
# 80.67/100: flooding: 2016/2499, 0.54, (126, 145)
# 81.63/100: flooding: 2040/2499, 0.56, (107, 170)
# 82.59/100: flooding: 2064/2499, 0.57, (101, 150)
# 83.55/100: flooding: 2088/2499, 0.59, (85, 131)
# 84.51/100: flooding: 2112/2499, 0.60, (121, 179)
# 85.47/100: flooding: 2136/2499, 0.61, (126, 147)
# 86.43/100: flooding: 2160/2499, 0.62, (82, 144)
# 87.39/100: flooding: 2184/2499, 0.64, (93, 128)
# 88.36/100: flooding: 2208/2499, 0.66, (122, 132)
# 89.32/100: flooding: 2232/2499, 0.68, (123, 150)
# 90.28/100: flooding: 2256/2499, 0.71, (96, 127)
# 91.24/100: flooding: 2280/2499, 0.72, (138, 150)
# 92.20/100: flooding: 2304/2499, 0.75, (137, 176)
# 93.16/100: flooding: 2328/2499, 0.79, (156, 160)
# 94.12/100: flooding: 2352/2499, 0.82, (98, 149)
# 95.08/100: flooding: 2376/2499, 0.85, (140, 176)
# 96.04/100: flooding: 2400/2499, 0.87, (136, 177)
# 97.00/100: flooding: 2424/2499, 0.89, (79, 133)
# 97.96/100: flooding: 2448/2499, 0.93, (84, 146)
# 98.92/100: flooding: 2472/2499, 0.99, (140, 148)
# 99.88/100: flooding: 2496/2499, 1.03, (135, 147)

# %%
clust.getclusters()
# Out:
# (array([[6, 6, 6, ..., 4, 4, 4],
#        [6, 6, 6, ..., 4, 4, 4],
#        [6, 6, 6, ..., 4, 4, 3],
#        ...,
#        [4, 4, 3, ..., 2, 2, 2],
#        [4, 4, 3, ..., 2, 2, 2],
#        [4, 4, 4, ..., 2, 2, 2]]),
#  array([[6, 6, 6, ..., 4, 4, 4],
#        [6, 6, 6, ..., 4, 4, 0],
#        [6, 6, 6, ..., 4, 0, 0],
#        ...,
#        [4, 0, 0, ..., 2, 2, 2],
#        [4, 0, 0, ..., 2, 2, 2],
#        [4, 4, 0, ..., 2, 2, 2]]))

# %%
clust.plotclusters()

# %%
clust.getGraph()

# %%
lm = asarray(SOMTools.detect_local_minima(clust.umat_cont)).T
lm = asarray(filter(lambda e: not clust.mask[e[0],e[1]], lm))
clust.plotclusters()
scatter(lm[:,1], lm[:,0], c='m')

# %%
reload(SOMgraph)
graph = SOMgraph.graph(clust.flood(som.smap)[0], mask = clust.mask)
graph.getgraph()

# %%
longestpath = asarray(graph.getLongestPath())

# %%
clust.plotclusters()
plot(longestpath[:,1], longestpath[:,0], 'w')
scatter(graph.localminima[:,1], graph.localminima[:,0], c='m')
