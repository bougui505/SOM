# %%
# %pylab inline
import sys
sys.path.append('.')
import sklearn.datasets
sys.path.append('../')
import GSOM
import SOMTools
import SOMclust
import SOMgraph
import itertools
import scipy.spatial.distance
from priodict import priorityDictionary
#pylab.rcParams['figure.figsize'] = 6, 6  # that's default image size for this interactive session
from IPython.display import clear_output
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload
# %autoreload 2

# %%
xy, c = sklearn.datasets.make_blobs(n_samples=5000, centers=5)
x, y = xy[:,0], xy[:,1]

# %%
scatter(x, y, c=c)

# %%
xy.shape
# Out:
# (5000, 2)

# %%
tmp = hist(scipy.spatial.distance.pdist(xy), 100)
grid()

# %%
#save('inputmatrix', xy)

# %%
gsom = GSOM.GSOM(xy, growing_threshold=0.2)
# Out:
# Map initialization...
# Shape of the SOM:(3, 3, 2)
# Map initialization...

# %%
smap = gsom.learn(verbose=True)
# Out:
# Learning for 5000 vectors
# 5000 iterations
# 50000 iterations
# Training phase 1 : 100%[========================================]Time: 00:00:06
# Training phase 2 : 100%[========================================]Time: 00:01:06

# %%
imshow(ma.masked_array(log(SOMTools.getUmatrix(gsom.smap, toricMap=False)), gsom.smap.mask[:,:,0]), interpolation='nearest'\
       , vmax=3)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x2ac346d66638>

# %%
matshow(gsom.smap.sum(axis=2))

# %%
plot(gsom.n_neurons[:,0], gsom.n_neurons[:,1])
grid()
