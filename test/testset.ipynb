# %%
import sys
sys.path.append('.')
import generatedatasets
sys.path.append('../')
import SOM2
import SOMTools
import SOMclust
import SOMgraph
import itertools
import scipy.spatial.distance
from priodict import priorityDictionary
pylab.rcParams['figure.figsize'] = 10, 10  # that's default image size for this interactive session
from IPython.display import clear_output

# %%
# %load_ext autoreload
# %autoreload 2

# %%
xy, c = generatedatasets.dataset_fixed_cov()
x, y = xy[:,0], xy[:,1]

# %%
scatter(x, y, c=c)

# %%
xy.shape
# Out:
# (600, 2)

# %%
#save('inputmatrix', xy)

# %%
som = SOM2.SOM(xy)

# %%
som.learn(verbose=True)
# Out:
# 0 0 600 0.00% 6.25 0.5 (25, 47)
# 0
#  100 600 16.67% 3.61384570922 0.297218900709 (32, 5)
# 0
#  200 600 33.33% 3.11594047838 0.258918498337 (31, 47)
# 0
#  300 600 50.00% 3.02189832775 0.25168448675 (9, 26)
# 0
#  400 600 66.67% 3.00413605985 0.25031815845 (33, 36)
# 0
#  500 600 83.33% 3.0007812008 0.250060092369 (36, 1)
# 1
#  0 1200 0.00% 4.0 0.25 (9, 17)
# 1
#  100 1200 8.33% 2.30379462552 0.108649552127 (15, 19)
# 1
#  200 1200 16.67% 1.56662680851 0.0472189007094 (45, 47)
# 1
#  300 1200 25.00% 1.24625499587 0.020521249656 (29, 48)
# 1
#  400 1200 33.33% 1.10702198004 0.00891849833681 (39, 43)
# 1
#  500 1200 41.67% 1.0465115608 0.00387596339975 (35, 36)
# 1
#  600 1200 50.00% 1.020213841 0.00168448674977 (9, 17)
# 1
#  700 1200 58.33% 1.00878489908 0.000732074923705 (15, 20)
# 1
#  800 1200 66.67% 1.0038179014 0.000318158450335 (45, 47)
# 1
#  900 1200 75.00% 1.00165925311 0.000138271092537 (29, 48)
# 1
#  1000 1200 83.33% 1.00072110843 6.00923691049e-05 (39, 43)
# 1
#  1100 1200 91.67% 1.00031339243 2.61160359579e-05 (32, 38)
# array([[[ 4.02597818,  4.87995299],
#         [ 3.96119771,  4.8526529 ],
#         [ 3.89371748,  4.8116008 ],
#         ...,
#         [ 4.20974897,  4.8902524 ],
#         [ 4.15325   ,  4.89592042],
#         [ 4.09018553,  4.89352978]],
#
#        [[ 3.97447747,  4.85381136],
#         [ 3.90788546,  4.82779205],
#         [ 3.83740455,  4.78747471],
#         ...,
#         [ 4.1558686 ,  4.85939051],
#         [ 4.1014687 ,  4.86748603],
#         [ 4.03924064,  4.86629715]],
#
#        [[ 3.9269015 ,  4.82442623],
#         [ 3.85912966,  4.80020284],
#         [ 3.78585806,  4.76103407],
#         ...,
#         [ 4.09815731,  4.82120728],
#         [ 4.04929332,  4.83389729],
#         [ 3.99064793,  4.83511495]],
#
#        ...,
#        [[ 4.20311773,  4.94069151],
#         [ 4.14066855,  4.90670802],
#         [ 4.07759794,  4.86265712],
#         ...,
#         [ 4.38111242,  4.97509992],
#         [ 4.32346367,  4.97269537],
#         [ 4.26395391,  4.96233923]],
#
#        [[ 4.14033531,  4.92278732],
#         [ 4.07760614,  4.89185097],
#         [ 4.01365802,  4.84917455],
#         ...,
#         [ 4.31807704,  4.94525329],
#         [ 4.26189756,  4.94662499],
#         [ 4.20185079,  4.94041123]],
#
#        [[ 4.08123396,  4.90275855],
#         [ 4.0178153 ,  4.87401149],
#         [ 3.95255223,  4.8322968 ],
#         ...,
#         [ 4.26239612,  4.91769058],
#         [ 4.20598574,  4.92150563],
#         [ 4.14413433,  4.91777732]]])

# %%
umat = SOMTools.getUmatrix(som.smap)

# %%
matshow(umat)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xdf02dd0>

# %%
bmus = som.get_allbmus()

# %%
reload(SOMclust)
clust = SOMclust.clusters(umat, bmus, som.smap)
# Out:
# 0.96/100: flooding: 24/2499, 0.04, (130, 102)
# 1.92/100: flooding: 48/2499, 0.05, (128, 99)
# 2.88/100: flooding: 72/2499, 0.05, (130, 95)
# 3.84/100: flooding: 96/2499, 0.05, (130, 106)
# 4.80/100: flooding: 120/2499, 0.06, (127, 97)
# 5.76/100: flooding: 144/2499, 0.06, (124, 98)
# 6.72/100: flooding: 168/2499, 0.06, (138, 93)
# 7.68/100: flooding: 192/2499, 0.07, (130, 109)
# 8.64/100: flooding: 216/2499, 0.07, (128, 94)
# 9.60/100: flooding: 240/2499, 0.07, (122, 103)
# 10.56/100: flooding: 264/2499, 0.08, (142, 91)
# 11.52/100: flooding: 288/2499, 0.08, (132, 111)
# 12.48/100: flooding: 312/2499, 0.07, (151, 100)
# 13.45/100: flooding: 336/2499, 0.07, (148, 101)
# 14.41/100: flooding: 360/2499, 0.08, (153, 97)
# 15.37/100: flooding: 384/2499, 0.09, (136, 92)
# 16.33/100: flooding: 408/2499, 0.09, (142, 100)
# 17.29/100: flooding: 432/2499, 0.09, (145, 95)
# 18.25/100: flooding: 456/2499, 0.10, (159, 100)
# 19.21/100: flooding: 480/2499, 0.06, (133, 87)
# 20.17/100: flooding: 504/2499, 0.10, (135, 91)
# 21.13/100: flooding: 528/2499, 0.11, (137, 88)
# 22.09/100: flooding: 552/2499, 0.11, (120, 102)
# 23.05/100: flooding: 576/2499, 0.11, (127, 93)
# 24.01/100: flooding: 600/2499, 0.12, (138, 85)
# 24.97/100: flooding: 624/2499, 0.14, (136, 83)
# 25.93/100: flooding: 648/2499, 0.15, (120, 103)
# 26.89/100: flooding: 672/2499, 0.15, (144, 89)
# 27.85/100: flooding: 696/2499, 0.17, (152, 94)
# 28.81/100: flooding: 720/2499, 0.18, (118, 102)
# 29.77/100: flooding: 744/2499, 0.20, (134, 80)
# 30.73/100: flooding: 768/2499, 0.22, (126, 109)
# 31.69/100: flooding: 792/2499, 0.23, (115, 102)
# 32.65/100: flooding: 816/2499, 0.26, (136, 111)
# 33.61/100: flooding: 840/2499, 0.29, (155, 105)
# 34.57/100: flooding: 864/2499, 0.31, (153, 106)
# 35.53/100: flooding: 888/2499, 0.34, (164, 103)
# 36.49/100: flooding: 912/2499, 0.37, (133, 114)
# 37.45/100: flooding: 936/2499, 0.41, (119, 105)
# 38.42/100: flooding: 960/2499, 0.44, (152, 107)
# 39.38/100: flooding: 984/2499, 0.48, (134, 114)
# 40.34/100: flooding: 1008/2499, 0.43, (132, 119)
# 41.30/100: flooding: 1032/2499, 0.05, (117, 121)
# 42.26/100: flooding: 1056/2499, 0.05, (115, 118)
# 43.22/100: flooding: 1080/2499, 0.05, (110, 116)
# 44.18/100: flooding: 1104/2499, 0.06, (120, 124)
# 45.14/100: flooding: 1128/2499, 0.06, (111, 123)
# 46.10/100: flooding: 1152/2499, 0.06, (109, 117)
# 47.06/100: flooding: 1176/2499, 0.06, (107, 124)
# 48.02/100: flooding: 1200/2499, 0.07, (122, 123)
# 48.98/100: flooding: 1224/2499, 0.07, (107, 123)
# 49.94/100: flooding: 1248/2499, 0.07, (102, 128)
# 50.90/100: flooding: 1272/2499, 0.08, (108, 133)
# 51.86/100: flooding: 1296/2499, 0.08, (111, 128)
# 52.82/100: flooding: 1320/2499, 0.08, (103, 124)
# 53.78/100: flooding: 1344/2499, 0.08, (99, 120)
# 54.74/100: flooding: 1368/2499, 0.08, (107, 120)
# 55.70/100: flooding: 1392/2499, 0.09, (107, 134)
# 56.66/100: flooding: 1416/2499, 0.09, (101, 127)
# 57.62/100: flooding: 1440/2499, 0.09, (114, 135)
# 58.58/100: flooding: 1464/2499, 0.10, (102, 131)
# 59.54/100: flooding: 1488/2499, 0.10, (115, 133)
# 60.50/100: flooding: 1512/2499, 0.11, (116, 136)
# 61.46/100: flooding: 1536/2499, 0.12, (99, 125)
# 62.42/100: flooding: 1560/2499, 0.12, (99, 126)
# 63.39/100: flooding: 1584/2499, 0.13, (95, 123)
# 64.35/100: flooding: 1608/2499, 0.14, (117, 138)
# 65.31/100: flooding: 1632/2499, 0.15, (90, 121)
# 66.27/100: flooding: 1656/2499, 0.17, (94, 124)
# 67.23/100: flooding: 1680/2499, 0.19, (107, 137)
# 68.19/100: flooding: 1704/2499, 0.21, (92, 117)
# 69.15/100: flooding: 1728/2499, 0.23, (111, 110)
# 70.11/100: flooding: 1752/2499, 0.25, (117, 140)
# 71.07/100: flooding: 1776/2499, 0.28, (103, 113)
# 72.03/100: flooding: 1800/2499, 0.31, (94, 126)
# 72.99/100: flooding: 1824/2499, 0.34, (100, 133)
# 73.95/100: flooding: 1848/2499, 0.37, (131, 120)
# 74.91/100: flooding: 1872/2499, 0.40, (98, 131)
# 75.87/100: flooding: 1896/2499, 0.43, (120, 139)
# 76.83/100: flooding: 1920/2499, 0.46, (123, 131)
# 77.79/100: flooding: 1944/2499, 0.49, (97, 113)
# 78.75/100: flooding: 1968/2499, 0.51, (124, 91)
# 79.71/100: flooding: 1992/2499, 0.53, (126, 88)
# 80.67/100: flooding: 2016/2499, 0.55, (127, 113)
# 81.63/100: flooding: 2040/2499, 0.56, (168, 95)
# 82.59/100: flooding: 2064/2499, 0.58, (148, 108)
# 83.55/100: flooding: 2088/2499, 0.60, (128, 82)
# 84.51/100: flooding: 2112/2499, 0.61, (86, 118)
# 85.47/100: flooding: 2136/2499, 0.63, (162, 105)
# 86.43/100: flooding: 2160/2499, 0.64, (167, 94)
# 87.39/100: flooding: 2184/2499, 0.65, (98, 133)
# 88.36/100: flooding: 2208/2499, 0.67, (108, 144)
# 89.32/100: flooding: 2232/2499, 0.69, (155, 92)
# 90.28/100: flooding: 2256/2499, 0.71, (131, 125)
# 91.24/100: flooding: 2280/2499, 0.72, (123, 138)
# 92.20/100: flooding: 2304/2499, 0.74, (124, 133)
# 93.16/100: flooding: 2328/2499, 0.76, (85, 117)
# 94.12/100: flooding: 2352/2499, 0.78, (108, 108)
# 95.08/100: flooding: 2376/2499, 0.80, (118, 108)
# 96.04/100: flooding: 2400/2499, 0.82, (151, 109)
# 97.00/100: flooding: 2424/2499, 0.84, (126, 83)
# 97.96/100: flooding: 2448/2499, 0.87, (140, 112)
# 98.92/100: flooding: 2472/2499, 0.91, (90, 127)
# 99.88/100: flooding: 2496/2499, 0.97, (87, 126)

# %%
clust.getclusters()
# Out:
# /c5/shared/Python/2.7.4-shared/lib/python2.7/site-packages/numpy/ma/core.py:3785: UserWarning: Warning: converting a masked element to nan.
#   warnings.warn("Warning: converting a masked element to nan.")
# (array([[ 7,  9,  9, ..., 14, 14,  9],
#        [ 7,  9,  9, ..., 14, 14, 14],
#        [ 7,  7,  9, ..., 14, 14, 14],
#        ...,
#        [ 4,  4,  4, ..., 11, 11,  7],
#        [ 4,  4,  4, ..., 11,  7,  7],
#        [ 4,  4,  4, ..., 11,  7,  7]]),
#  array([[ 0,  0,  9, ...,  0,  0,  0],
#        [ 0,  0,  9, ...,  0, 14,  0],
#        [ 0,  0,  0, ...,  0, 14, 14],
#        ...,
#        [ 4,  4,  4, ..., 11,  0,  0],
#        [ 4,  4,  4, ...,  0,  0,  7],
#        [ 4,  4,  4, ...,  0,  0,  7]]))

# %%
clust.plotclusters()

# %%
clust.getGraph()

# %%
lm = asarray(SOMTools.detect_local_minima(clust.umat_cont)).T
lm = asarray(filter(lambda e: not clust.mask[e[0],e[1]], lm))
clust.plotclusters()
scatter(lm[:,1], lm[:,0], c='m')

# %%
reload(SOMgraph)
graph = SOMgraph.graph(clust.flood(som.smap)[0], mask = clust.mask)
graph.getgraph()
print len(graph.graph)
# Out:
# 2500

# %%
longestpath = asarray(graph.getLongestPath())
print longestpath.shape
#print graph.localminimagraph
print len(graph.graph)
# Out:
# (40, 2)
# 2500

# %%
clust.plotclusters()
plot(longestpath[:,1], longestpath[:,0], 'w')
scatter(graph.localminima[:,1], graph.localminima[:,0], c='m')

# %%
clust.plotclusters()
scatter(graph.localminima[:,1], graph.localminima[:,0], c='m')
mingraph = graph.clean_graph()
for n1 in mingraph.keys():
    for n2 in mingraph[n1].keys():
        v = asarray((n1,n2))
        plot(v[:,1],v[:,0], 'w')

# %%
clust.plotclusters()
longestpath = asarray(graph.getLongestPath(localmin=True))
plot(longestpath[:,1], longestpath[:,0], 'w')
scatter(graph.localminima[:,1], graph.localminima[:,0], c='m')
