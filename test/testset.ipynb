# %%
import sys
sys.path.append('.')
import sklearn.datasets
sys.path.append('../')
import SOM2
import SOMTools
import SOMclust
import SOMgraph
import itertools
import scipy.spatial.distance
from priodict import priorityDictionary
pylab.rcParams['figure.figsize'] = 10, 10  # that's default image size for this interactive session
from IPython.display import clear_output

# %%
# %load_ext autoreload
# %autoreload 2

# %%
xy, c = sklearn.datasets.make_blobs(n_samples=5000, centers=10)
x, y = xy[:,0], xy[:,1]

# %%
scatter(x, y, c=c)

# %%
xy.shape
# Out:
# (5000, 2)

# %%
#save('inputmatrix', xy)

# %%
som = SOM2.SOM(xy)

# %%
smap = som.learn(verbose=True)
# Out:
# 1 9999 10000 99.99% 1.00013633606 1.13613380999e-05 (6, 16)

# %%
umat = SOMTools.getUmatrix(som.smap)

# %%
matshow(umat)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xa6e9d88>

# %%
bmudists = asarray([som.findbmu(som.smap, e, returndist=True) for e in som.input_matrix])
bmus = bmudists[:,:2]

# %%
reload(SOMclust)
clust = SOMclust.clusters(umat, bmus, som.smap)
# Out:
# 100.00/100: flooding: 2499/2499, 3.13, (160, 110)

# %%
reload(SOMgraph)
graph = SOMgraph.graph(clust.flood(som.smap)[0], mask = clust.mask)
graph.getgraph()

# %%
g = graph.clean_graph()

# %%
graph.plot_graph(graph.mingraph, plotpath=True, plotnode=True, plotUmat=True
, plotclusters=True, color='k')

# %%
indexmap = som.getmatindex()
# Out:
# computing distances and bmus
