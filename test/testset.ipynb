# %%
import sys
sys.path.append('.')
import generatedatasets
sys.path.append('../')
import SOM2
import SOMTools
import SOMclust
import SOMgraph
import itertools
import scipy.spatial.distance
from priodict import priorityDictionary
pylab.rcParams['figure.figsize'] = 10, 10  # that's default image size for this interactive session
from IPython.display import clear_output

# %%
# %load_ext autoreload
# %autoreload 2

# %%
xy, c = generatedatasets.dataset_fixed_cov()
x, y = xy[:,0], xy[:,1]

# %%
scatter(x, y, c=c)

# %%
xy.shape
# Out:
# (600, 2)

# %%
#save('inputmatrix', xy)

# %%
som = SOM2.SOM(xy)

# %%
som.learn(verbose=True)
# Out:
# 0 0 600 0.00% 6.25 0.5 (36, 11)
# 0
#  100 600 16.67% 3.61384570922 0.297218900709 (22, 22)
# 0
#  200 600 33.33% 3.11594047838 0.258918498337 (13, 19)
# 0
#  300 600 50.00% 3.02189832775 0.25168448675 (16, 25)
# 0
#  400 600 66.67% 3.00413605985 0.25031815845 (39, 3)
# 0
#  500 600 83.33% 3.0007812008 0.250060092369 (28, 5)
# 1
#  0 1200 0.00% 4.0 0.25 (37, 4)
# 1
#  100 1200 8.33% 2.30379462552 0.108649552127 (18, 26)
# 1
#  200 1200 16.67% 1.56662680851 0.0472189007094 (35, 3)
# 1
#  300 1200 25.00% 1.24625499587 0.020521249656 (22, 30)
# 1
#  400 1200 33.33% 1.10702198004 0.00891849833681 (18, 44)
# 1
#  500 1200 41.67% 1.0465115608 0.00387596339975 (29, 42)
# 1
#  600 1200 50.00% 1.020213841 0.00168448674977 (37, 5)
# 1
#  700 1200 58.33% 1.00878489908 0.000732074923705 (18, 26)
# 1
#  800 1200 66.67% 1.0038179014 0.000318158450335 (35, 3)
# 1
#  900 1200 75.00% 1.00165925311 0.000138271092537 (13, 15)
# 1
#  1000 1200 83.33% 1.00072110843 6.00923691049e-05 (18, 44)
# 1
#  1100 1200 91.67% 1.00031339243 2.61160359579e-05 (29, 42)
# array([[[ 0.78451115,  0.08826381],
#         [ 0.83529539,  0.08054023],
#         [ 0.88963557,  0.07918699],
#         ...,
#         [ 0.67678032,  0.15490972],
#         [ 0.70432773,  0.1253572 ],
#         [ 0.74040478,  0.10315466]],
#
#        [[ 0.85157588,  0.12994733],
#         [ 0.90350261,  0.12241646],
#         [ 0.95852621,  0.12094008],
#         ...,
#         [ 0.74133434,  0.19544344],
#         [ 0.76952035,  0.16614859],
#         [ 0.80643691,  0.14445983]],
#
#        [[ 0.91070511,  0.1747615 ],
#         [ 0.9626199 ,  0.16773128],
#         [ 1.01714753,  0.16647035],
#         ...,
#         [ 0.80269957,  0.23940822],
#         [ 0.82940377,  0.20967506],
#         [ 0.86567955,  0.188607  ]],
#
#        ...,
#        [[ 0.55621601, -0.01138436],
#         [ 0.59346153, -0.02107065],
#         [ 0.63570801, -0.02328948],
#         ...,
#         [ 0.49039424,  0.06042836],
#         [ 0.50441195,  0.02951851],
#         [ 0.52624396,  0.00550929]],
#
#        [[ 0.6349868 ,  0.01836589],
#         [ 0.67827225,  0.00913004],
#         [ 0.72591705,  0.00695579],
#         ...,
#         [ 0.55021826,  0.08853336],
#         [ 0.57011506,  0.05810379],
#         [ 0.59849606,  0.03468466]],
#
#        [[ 0.71157116,  0.05112175],
#         [ 0.75953849,  0.04284476],
#         [ 0.81142829,  0.04127227],
#         ...,
#         [ 0.61224562,  0.11928276],
#         [ 0.63688178,  0.08930154],
#         [ 0.6702207 ,  0.06656949]]])

# %%
umat = SOMTools.getUmatrix(som.smap)

# %%
matshow(umat)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x2b79191ef320>

# %%
bmus = som.get_allbmus()

# %%
reload(SOMclust)
clust = SOMclust.clusters(umat, bmus, som.smap)
# Out:
# 0.96/100: flooding: 24/2499, 0.06, (107, 153)
# 1.92/100: flooding: 48/2499, 0.07, (103, 150)
# 2.88/100: flooding: 72/2499, 0.07, (100, 147)
# 3.84/100: flooding: 96/2499, 0.05, (90, 150)
# 4.80/100: flooding: 120/2499, 0.06, (89, 153)
# 5.76/100: flooding: 144/2499, 0.06, (88, 148)
# 6.72/100: flooding: 168/2499, 0.07, (84, 151)
# 7.68/100: flooding: 192/2499, 0.07, (97, 144)
# 8.64/100: flooding: 216/2499, 0.07, (90, 158)
# 9.60/100: flooding: 240/2499, 0.07, (93, 157)
# 10.56/100: flooding: 264/2499, 0.08, (95, 153)
# 11.52/100: flooding: 288/2499, 0.08, (95, 154)
# 12.48/100: flooding: 312/2499, 0.08, (99, 152)
# 13.45/100: flooding: 336/2499, 0.08, (104, 157)
# 14.41/100: flooding: 360/2499, 0.09, (76, 150)
# 15.37/100: flooding: 384/2499, 0.09, (98, 143)
# 16.33/100: flooding: 408/2499, 0.06, (78, 140)
# 17.29/100: flooding: 432/2499, 0.08, (75, 144)
# 18.25/100: flooding: 456/2499, 0.09, (77, 146)
# 19.21/100: flooding: 480/2499, 0.09, (73, 151)
# 20.17/100: flooding: 504/2499, 0.10, (83, 145)
# 21.13/100: flooding: 528/2499, 0.10, (99, 158)
# 22.09/100: flooding: 552/2499, 0.10, (89, 144)
# 23.05/100: flooding: 576/2499, 0.11, (113, 152)
# 24.01/100: flooding: 600/2499, 0.11, (109, 155)
# 24.97/100: flooding: 624/2499, 0.12, (94, 141)
# 25.93/100: flooding: 648/2499, 0.13, (70, 148)
# 26.89/100: flooding: 672/2499, 0.14, (73, 153)
# 27.85/100: flooding: 696/2499, 0.14, (95, 160)
# 28.81/100: flooding: 720/2499, 0.15, (104, 145)
# 29.77/100: flooding: 744/2499, 0.16, (81, 138)
# 30.73/100: flooding: 768/2499, 0.17, (113, 146)
# 31.69/100: flooding: 792/2499, 0.19, (71, 153)
# 32.65/100: flooding: 816/2499, 0.20, (82, 158)
# 33.61/100: flooding: 840/2499, 0.23, (73, 139)
# 34.57/100: flooding: 864/2499, 0.25, (77, 137)
# 35.53/100: flooding: 888/2499, 0.28, (78, 157)
# 36.49/100: flooding: 912/2499, 0.31, (80, 158)
# 37.45/100: flooding: 936/2499, 0.34, (87, 136)
# 38.42/100: flooding: 960/2499, 0.37, (103, 161)
# 39.38/100: flooding: 984/2499, 0.41, (77, 136)
# 40.34/100: flooding: 1008/2499, 0.45, (101, 162)
# 41.30/100: flooding: 1032/2499, 0.49, (102, 162)
# 42.26/100: flooding: 1056/2499, 0.53, (72, 156)
# 43.22/100: flooding: 1080/2499, 0.55, (110, 143)
# 44.18/100: flooding: 1104/2499, 0.14, (111, 136)
# 45.14/100: flooding: 1128/2499, 0.06, (111, 127)
# 46.10/100: flooding: 1152/2499, 0.07, (112, 123)
# 47.06/100: flooding: 1176/2499, 0.07, (109, 127)
# 48.02/100: flooding: 1200/2499, 0.06, (100, 124)
# 48.98/100: flooding: 1224/2499, 0.06, (95, 126)
# 49.94/100: flooding: 1248/2499, 0.06, (101, 124)
# 50.90/100: flooding: 1272/2499, 0.07, (102, 123)
# 51.86/100: flooding: 1296/2499, 0.07, (97, 129)
# 52.82/100: flooding: 1320/2499, 0.07, (111, 119)
# 53.78/100: flooding: 1344/2499, 0.07, (103, 130)
# 54.74/100: flooding: 1368/2499, 0.08, (116, 116)
# 55.70/100: flooding: 1392/2499, 0.08, (117, 120)
# 56.66/100: flooding: 1416/2499, 0.05, (128, 121)
# 57.62/100: flooding: 1440/2499, 0.08, (125, 119)
# 58.58/100: flooding: 1464/2499, 0.08, (114, 133)
# 59.54/100: flooding: 1488/2499, 0.09, (119, 117)
# 60.50/100: flooding: 1512/2499, 0.09, (122, 125)
# 61.46/100: flooding: 1536/2499, 0.09, (113, 134)
# 62.42/100: flooding: 1560/2499, 0.10, (130, 122)
# 63.39/100: flooding: 1584/2499, 0.10, (120, 128)
# 64.35/100: flooding: 1608/2499, 0.11, (95, 120)
# 65.31/100: flooding: 1632/2499, 0.12, (93, 129)
# 66.27/100: flooding: 1656/2499, 0.13, (125, 126)
# 67.23/100: flooding: 1680/2499, 0.14, (123, 115)
# 68.19/100: flooding: 1704/2499, 0.15, (128, 126)
# 69.15/100: flooding: 1728/2499, 0.16, (100, 119)
# 70.11/100: flooding: 1752/2499, 0.18, (120, 113)
# 71.07/100: flooding: 1776/2499, 0.19, (127, 127)
# 72.03/100: flooding: 1800/2499, 0.20, (117, 112)
# 72.99/100: flooding: 1824/2499, 0.21, (123, 114)
# 73.95/100: flooding: 1848/2499, 0.23, (108, 137)
# 74.91/100: flooding: 1872/2499, 0.25, (126, 128)
# 75.87/100: flooding: 1896/2499, 0.28, (120, 112)
# 76.83/100: flooding: 1920/2499, 0.30, (114, 112)
# 77.79/100: flooding: 1944/2499, 0.33, (85, 118)
# 78.75/100: flooding: 1968/2499, 0.37, (115, 111)
# 79.71/100: flooding: 1992/2499, 0.40, (88, 129)
# 80.67/100: flooding: 2016/2499, 0.43, (114, 111)
# 81.63/100: flooding: 2040/2499, 0.47, (116, 110)
# 82.59/100: flooding: 2064/2499, 0.51, (99, 135)
# 83.55/100: flooding: 2088/2499, 0.55, (84, 129)
# 84.51/100: flooding: 2112/2499, 0.58, (92, 133)
# 85.47/100: flooding: 2136/2499, 0.60, (93, 164)
# 86.43/100: flooding: 2160/2499, 0.62, (89, 134)
# 87.39/100: flooding: 2184/2499, 0.63, (86, 133)
# 88.36/100: flooding: 2208/2499, 0.65, (98, 164)
# 89.32/100: flooding: 2232/2499, 0.66, (98, 115)
# 90.28/100: flooding: 2256/2499, 0.68, (119, 156)
# 91.24/100: flooding: 2280/2499, 0.69, (111, 110)
# 92.20/100: flooding: 2304/2499, 0.70, (85, 162)
# 93.16/100: flooding: 2328/2499, 0.72, (94, 135)
# 94.12/100: flooding: 2352/2499, 0.76, (119, 109)
# 95.08/100: flooding: 2376/2499, 0.80, (115, 139)
# 96.04/100: flooding: 2400/2499, 0.85, (116, 140)
# 97.00/100: flooding: 2424/2499, 0.88, (119, 136)
# 97.96/100: flooding: 2448/2499, 0.93, (123, 110)
# 98.92/100: flooding: 2472/2499, 0.99, (73, 135)
# 99.88/100: flooding: 2496/2499, 1.08, (76, 133)

# %%
clust.getclusters()
# Out:
# /c5/shared/Python/2.7.4-shared/lib/python2.7/site-packages/numpy/ma/core.py:3785: UserWarning: Warning: converting a masked element to nan.
#   warnings.warn("Warning: converting a masked element to nan.")
# (array([[1, 1, 1, ..., 3, 3, 3],
#        [1, 1, 1, ..., 3, 3, 3],
#        [1, 1, 1, ..., 3, 3, 3],
#        ...,
#        [6, 6, 2, ..., 2, 1, 1],
#        [6, 6, 6, ..., 2, 1, 1],
#        [6, 6, 6, ..., 2, 2, 1]]),
#  array([[0, 1, 1, ..., 3, 3, 3],
#        [0, 1, 1, ..., 3, 3, 3],
#        [0, 1, 0, ..., 3, 3, 3],
#        ...,
#        [6, 0, 0, ..., 0, 0, 0],
#        [6, 6, 0, ..., 0, 0, 1],
#        [6, 6, 0, ..., 2, 0, 0]]))

# %%
clust.plotclusters()

# %%
clust.getGraph()

# %%
lm = asarray(SOMTools.detect_local_minima(clust.umat_cont)).T
lm = asarray(filter(lambda e: not clust.mask[e[0],e[1]], lm))
clust.plotclusters()
scatter(lm[:,1], lm[:,0], c='m')

# %%
reload(SOMgraph)
graph = SOMgraph.graph(clust.flood(som.smap)[0], mask = clust.mask)
graph.getgraph()
print len(graph.graph)
# Out:
# 2500

# %%
longestpath = asarray(graph.getLongestPath())
print longestpath.shape
#print graph.localminimagraph
print len(graph.graph)
# Out:
# (51, 2)
# 2500

# %%
clust.plotclusters()
plot(longestpath[:,1], longestpath[:,0], 'w')
scatter(graph.localminima[:,1], graph.localminima[:,0], c='m')

# %%
clust.plotclusters()
scatter(graph.localminima[:,1], graph.localminima[:,0], c='m')
graph.plot_graph(graph.localminimagraph, 'w')

# %%
clust.plotclusters()
scatter(graph.localminima[:,1], graph.localminima[:,0], c='m')
subgraph = graph.clean_graph(graph.localminimagraph)
graph.plot_graph(subgraph, 'w')
