# %% [markdown]
# # SOM tutorial with a 2D test set

# %% [markdown]
# ## Imports

# %%
import sys
sys.path.append('.')
sys.path.append('../')
import generatedatasets
import SOM2
import SOMclust
from pylab import *
pylab.rcParams['figure.figsize'] = 10, 10  # that's default image size for this interactive session

# %% [markdown]
# ## Generate dataset

# %%
xy, c = generatedatasets.dataset_fixed_cov()

# %%
scatter(*xy.T, c=c)

# %%
xy.shape
# Out:
# (4000, 2)

# %% [markdown]
# ## Learn

# %%
som = SOM2.SOM(xy)

# %%
smap = som.learn(verbose=True)
# Out:
# 1 7999 8000 99.99% 1.00013637015 1.13641787895e-05 (47, 15)

# %% [markdown]
# ## and U-matrix

# %%
umat = som.umatrix()

# %%
matshow(umat)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x15e66518>

# %% [markdown]
# ## Compute BMUs -- the position of each input data in the SOM

# %%
bmus = som.get_allbmus()

# %% [markdown]
# ## Flood the map to deal with the torus

# %%
clust = SOMclust.clusters(umat, bmus, som.smap)
# Out:
# 100.00/100: flooding: 2499/2499, 1.32, (150, 102)

# %%
imshow(ma.masked_array(clust.umat_cont, clust.mask), interpolation='nearest')
