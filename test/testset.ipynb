# %%
import sys
sys.path.append('.')
import sklearn.datasets
sys.path.append('../')
import SOM2
import SOMTools
import SOMclust
import SOMgraph
import itertools
import scipy.spatial.distance
from priodict import priorityDictionary
pylab.rcParams['figure.figsize'] = 10, 10  # that's default image size for this interactive session
from IPython.display import clear_output

# %%
# %load_ext autoreload
# %autoreload 2

# %%
xy, c = sklearn.datasets.make_blobs(n_samples=5000, centers=2)
x, y = xy[:,0], xy[:,1]

# %%
scatter(x, y, c=c)

# %%
xy.shape
# Out:
# (5000, 2)

# %%
#save('inputmatrix', xy)

# %%
som = SOM2.SOM(xy)

# %%
smap = som.learn(verbose=True)
# Out:
# 1 9999 10000 99.99% 1.00013633606 1.13613380999e-05 (3, 0)

# %%
umat = SOMTools.getUmatrix(som.smap)

# %%
matshow(umat)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x2b073c145d40>

# %%
bmus = som.get_allbmus()

# %%
reload(SOMclust)
clust = SOMclust.clusters(umat, bmus, som.smap)
# Out:
# 100.00/100: flooding: 2499/2499, 0.65, (141, 150)

# %%
reload(SOMgraph)
graph = SOMgraph.graph(clust.flood(som.smap)[0], mask = clust.mask)
graph.getgraph()

# %%
g = graph.clean_graph()

# %%
graph.plot_graph(graph.mingraph, plotpath=True, plotnode=True, plotUmat=False, plotclusters=True, color='k')
