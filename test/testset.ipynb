# %%
import syssys.path.append('.')import generatedatasets

# %%
xy, c = generatedatasets.dataset_fixed_cov()x, y = xy[:,0], xy[:,1]

# %%
scatter(x, y, c=c)
# Out:
# &lt;matplotlib.collections.PathCollection at 0xfcbcad0&gt;

# %%
xy.shape
# Out:
# (600, 2)

# %%
#save('inputmatrix', xy)
